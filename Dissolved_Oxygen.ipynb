# %% [markdown]
# ## BPNN

# %%
import time
import numpy
from math import sqrt
from numpy import concatenate
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,SimpleRNN,GRU,Bidirectional
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]


    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  
values = dataset.values
values = values.astype('float32')  
scaler = MinMaxScaler(feature_range=(0, 1))    
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1) 
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
regressorBKP = Sequential()
regressorBKP.add(Dense(units = 500, kernel_initializer = 'uniform',  input_dim = 1))
regressorBKP.add(Dropout(0.2))
regressorBKP.add(Dense(units = 500, kernel_initializer = 'uniform'))
regressorBKP.add(Dropout(0.2))
regressorBKP.add(Dense(units = 500, kernel_initializer = 'uniform'))
regressorBKP.add(Dropout(0.2))
regressorBKP.add(Dense(units = 500, kernel_initializer = 'uniform'))
regressorBKP.add(Dropout(0.2))
regressorBKP.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
regressorBKP.compile(optimizer = 'adam', loss = 'mean_squared_error')
start = time.time()
print("Compilation Time : ", time.time() - start)

history = regressorBKP.fit(train_X, train_y, epochs = 200, batch_size = 32 ,validation_data=(test_X, test_y), verbose=1,
                    shuffle=False)
# Out:
# Compilation Time :  4.100799560546875e-05
# Epoch 1/200
# 20/20 [==============================] - 1s 18ms/step - loss: 0.0625 - val_loss: 0.0261
# Epoch 2/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0177 - val_loss: 0.0125
# Epoch 3/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0164 - val_loss: 0.0050
# Epoch 4/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0051
# Epoch 5/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0048
# Epoch 6/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0047
# Epoch 7/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0091 - val_loss: 0.0046
# Epoch 8/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0115 - val_loss: 0.0050
# Epoch 9/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0145 - val_loss: 0.0069
# Epoch 10/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0154 - val_loss: 0.0083
# Epoch 11/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0141 - val_loss: 0.0089
# Epoch 12/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0127 - val_loss: 0.0088
# Epoch 13/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0100 - val_loss: 0.0072
# Epoch 14/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0089 - val_loss: 0.0053
# Epoch 15/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0047
# Epoch 16/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 17/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 18/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0060
# Epoch 19/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0091 - val_loss: 0.0062
# Epoch 20/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0094 - val_loss: 0.0068
# Epoch 21/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0069
# Epoch 22/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0093 - val_loss: 0.0067
# Epoch 23/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0086 - val_loss: 0.0069
# Epoch 24/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0081 - val_loss: 0.0063
# Epoch 25/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0078 - val_loss: 0.0065
# Epoch 26/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0079 - val_loss: 0.0061
# Epoch 27/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 28/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 29/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 30/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 31/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0078 - val_loss: 0.0059
# Epoch 32/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0062
# Epoch 33/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0060
# Epoch 34/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0064
# Epoch 35/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0056
# Epoch 36/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0079 - val_loss: 0.0060
# Epoch 37/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 0.0062
# Epoch 38/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0057
# Epoch 39/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 40/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0053
# Epoch 41/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0054
# Epoch 42/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 43/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 44/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0058
# Epoch 45/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0088 - val_loss: 0.0059
# Epoch 46/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0086 - val_loss: 0.0061
# Epoch 47/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0082 - val_loss: 0.0059
# Epoch 48/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0075
# Epoch 49/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0060
# Epoch 50/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 51/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0054
# Epoch 52/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0050
# Epoch 53/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0048
# Epoch 54/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 55/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 56/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 57/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0065
# Epoch 58/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0064
# Epoch 59/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 60/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 61/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 62/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 63/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 64/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0058
# Epoch 65/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 66/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0076 - val_loss: 0.0060
# Epoch 67/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0059
# Epoch 68/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0074 - val_loss: 0.0057
# Epoch 69/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0058
# Epoch 70/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0055
# Epoch 71/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 72/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0058
# Epoch 73/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 74/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0068
# Epoch 75/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0126
# Epoch 76/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 77/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 78/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 79/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0056
# Epoch 80/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0064
# Epoch 81/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 82/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 83/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0572
# Epoch 84/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0046
# Epoch 85/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 86/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 87/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0167
# Epoch 88/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0048
# Epoch 89/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0100 - val_loss: 0.0249
# Epoch 90/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0123 - val_loss: 0.0309
# Epoch 91/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0175
# Epoch 92/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0084 - val_loss: 0.0047
# Epoch 93/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 94/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 95/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0056
# Epoch 96/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0052
# Epoch 97/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0062
# Epoch 98/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0093 - val_loss: 0.0068
# Epoch 99/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0084 - val_loss: 0.0064
# Epoch 100/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0083 - val_loss: 0.0068
# Epoch 101/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0077
# Epoch 102/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0085 - val_loss: 0.0068
# Epoch 103/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0053
# Epoch 104/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0049
# Epoch 105/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 106/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0056
# Epoch 107/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 108/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0065
# Epoch 109/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 110/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 111/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 112/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 113/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 114/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 115/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0056
# Epoch 116/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 117/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 118/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 119/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 120/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 121/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 122/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 123/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 124/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 125/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 126/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0061
# Epoch 127/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0061
# Epoch 128/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0059
# Epoch 129/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 130/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 131/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0056
# Epoch 132/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 133/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 134/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 135/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 136/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 137/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 138/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 139/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 140/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 141/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 142/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 143/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0057
# Epoch 144/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 145/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 146/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 147/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 148/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 149/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 150/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 151/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 152/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 153/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0056
# Epoch 154/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 155/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0055
# Epoch 156/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 157/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0078
# Epoch 158/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0097
# Epoch 159/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 160/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 161/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0177
# Epoch 162/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0083 - val_loss: 0.0091
# Epoch 163/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 164/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 165/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0223
# Epoch 166/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0079
# Epoch 167/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 168/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0176
# Epoch 169/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 170/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 171/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 172/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0510
# Epoch 173/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0113 - val_loss: 0.0078
# Epoch 174/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0074
# Epoch 175/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 176/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0078
# Epoch 177/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0092
# Epoch 178/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0083 - val_loss: 0.0077
# Epoch 179/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0078 - val_loss: 0.0151
# Epoch 180/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0156
# Epoch 181/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0052
# Epoch 182/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 183/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0137
# Epoch 184/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0129
# Epoch 185/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0110 - val_loss: 0.0182
# Epoch 186/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0087 - val_loss: 0.0048
# Epoch 187/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 188/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0063 - val_loss: 0.0078
# Epoch 189/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0099 - val_loss: 0.0080
# Epoch 190/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0091 - val_loss: 0.0075
# Epoch 191/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 192/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0093 - val_loss: 0.0059
# Epoch 193/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 194/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0049
# Epoch 195/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 196/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 197/200
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 198/200
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 199/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 200/200
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0055

# %%
pyplot.figure(2)
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
train_xhat=regressorBKP.predict(train_X)
yhat = regressorBKP.predict(test_X)

# %%
trainPredict = scaler.inverse_transform(train_xhat)
train_yhat = scaler.inverse_transform([train_y])
testPredict = scaler.inverse_transform(yhat)
test_yhat = scaler.inverse_transform([test_y])

# %%
look_back= 1

trainPredictPlot = numpy.empty_like(scaled)    
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = numpy.empty_like(scaled)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):len(scaled)-1, :] = testPredict
pyplot.figure(figsize = (20, 4))
pyplot.plot(scaler.inverse_transform(scaled))
pyplot.plot(trainPredictPlot)
pyplot.plot(testPredictPlot)
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test Score: %.4f RMSE' % rmse)
test2 = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (test2))
test = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (test))
# Out:
# Test Score: 0.5863 RMSE
# Test Score: 0.3438 MAE
# Test Score: 0.0879 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()

# %% [markdown]
# ## SVR

# %%
from math import sqrt
from numpy import concatenate
import numpy as np
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from matplotlib import pyplot

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  
values = dataset.values
values = values.astype('float32')  
scaler = MinMaxScaler(feature_range=(0, 1))    
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1) 
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# %%
clf = SVR(C=1.0, kernel='sigmoid', degree=3, gamma = 0.1, max_iter=10000)

clf.fit(train_X,train_y)

# make a prediction
predict_y = clf.predict(test_X)
yhat = predict_y.reshape(predict_y.shape[0],1)
test_X = test_X.reshape((test_X.shape[0],test_X.shape[1]))
print(yhat.shape,test_X.shape)
# invert scaling for forecast
inv_yhat = concatenate((test_X[:, -24:-1], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_X[:, -24:-1], test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.4f' % rmse)
mae = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (mae))
mape = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (mape))
# Out:
# (95, 1) (95, 1)
# Test RMSE: 0.5517
# Test Score: 0.3044 MAE
# Test Score: 0.0778 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()

# %% [markdown]
# ## SRN

# %%
import time
import numpy
from math import sqrt
from numpy import concatenate
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,SimpleRNN
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]


    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  #header 第一列为编号  index_col为取索引的参数
values = dataset.values
values = values.astype('float32')  #转化为浮点型
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))    #归一化处理
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)  #转化为监督学习  设计预测维数
# drop columns we don't want to predict
#reframed.drop(reframed.columns[[5,6,7]], axis=1, inplace=True) #reframed.drop 删除不预测的列
print(reframed.head())
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
model = Sequential()
model.add(SimpleRNN(units = 500, return_sequences = True, input_shape = (train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(SimpleRNN(units = 500, return_sequences = True))
model.add(Dropout(0.2))
model.add(SimpleRNN(units = 500, return_sequences = True))
model.add(Dropout(0.2))
model.add(SimpleRNN(units = 500, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units = 1,activation = 'linear'))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
start = time.time()
print("Compilation Time : ", time.time() - start)

history = model.fit(train_X, train_y, epochs = 200, batch_size = 32 ,validation_data=(test_X, test_y), verbose=1,
                    shuffle=False)
# Out:
#    var1(t-1)   var1(t)
# 1   0.746835  0.696203
# 2   0.696203  0.721519
# 3   0.721519  0.721519
# 4   0.721519  0.708861
# 5   0.708861  0.632911
# Compilation Time :  6.937980651855469e-05
# Epoch 1/200
# 20/20 [==============================] - 4s 60ms/step - loss: 0.1198 - val_loss: 0.0474
# Epoch 2/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0373 - val_loss: 0.0056
# Epoch 3/200
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 4/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0064 - val_loss: 0.0047
# Epoch 5/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 6/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 7/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 8/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0061 - val_loss: 0.0047
# Epoch 9/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0062 - val_loss: 0.0047
# Epoch 10/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 11/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0069 - val_loss: 0.0047
# Epoch 12/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0071 - val_loss: 0.0047
# Epoch 13/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0048
# Epoch 14/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0078 - val_loss: 0.0046
# Epoch 15/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0088 - val_loss: 0.0047
# Epoch 16/200
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0111 - val_loss: 0.0053
# Epoch 17/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0136 - val_loss: 0.0077
# Epoch 18/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0154 - val_loss: 0.0086
# Epoch 19/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0140 - val_loss: 0.0077
# Epoch 20/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0121 - val_loss: 0.0060
# Epoch 21/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0104 - val_loss: 0.0057
# Epoch 22/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0095 - val_loss: 0.0066
# Epoch 23/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0098 - val_loss: 0.0078
# Epoch 24/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0088 - val_loss: 0.0069
# Epoch 25/200
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 26/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 27/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0069 - val_loss: 0.0059
# Epoch 28/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 29/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 30/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0070 - val_loss: 0.0059
# Epoch 31/200
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 32/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 33/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 34/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0073 - val_loss: 0.0061
# Epoch 35/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 36/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0072 - val_loss: 0.0058
# Epoch 37/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0073 - val_loss: 0.0061
# Epoch 38/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 39/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 40/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0075 - val_loss: 0.0061
# Epoch 41/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 42/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0063
# Epoch 43/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0072 - val_loss: 0.0058
# Epoch 44/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 45/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 46/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 47/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 48/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0076 - val_loss: 0.0059
# Epoch 49/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 50/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0060
# Epoch 51/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0080 - val_loss: 0.0063
# Epoch 52/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0079 - val_loss: 0.0064
# Epoch 53/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 54/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0073 - val_loss: 0.0059
# Epoch 55/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0064
# Epoch 56/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 57/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 58/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 59/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0079 - val_loss: 0.0063
# Epoch 60/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 61/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 62/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 63/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 64/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0073 - val_loss: 0.0063
# Epoch 65/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 66/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 67/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 68/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0065
# Epoch 69/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 70/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 71/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 72/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0068 - val_loss: 0.0059
# Epoch 73/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0071 - val_loss: 0.0058
# Epoch 74/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 75/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0072 - val_loss: 0.0058
# Epoch 76/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 77/200
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 78/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 79/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 80/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 81/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0082 - val_loss: 0.0063
# Epoch 82/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0079 - val_loss: 0.0059
# Epoch 83/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0060
# Epoch 84/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0072 - val_loss: 0.0057
# Epoch 85/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 86/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0076 - val_loss: 0.0059
# Epoch 87/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0077 - val_loss: 0.0060
# Epoch 88/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0074 - val_loss: 0.0063
# Epoch 89/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0075 - val_loss: 0.0061
# Epoch 90/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0076 - val_loss: 0.0059
# Epoch 91/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0074 - val_loss: 0.0061
# Epoch 92/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 93/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 94/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0078 - val_loss: 0.0058
# Epoch 95/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 96/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0076 - val_loss: 0.0060
# Epoch 97/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0057
# Epoch 98/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0074 - val_loss: 0.0061
# Epoch 99/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0077 - val_loss: 0.0060
# Epoch 100/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0059
# Epoch 101/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0076 - val_loss: 0.0057
# Epoch 102/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0080 - val_loss: 0.0057
# Epoch 103/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0076 - val_loss: 0.0056
# Epoch 104/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 105/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 106/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 107/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0074 - val_loss: 0.0051
# Epoch 108/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0066 - val_loss: 0.0050
# Epoch 109/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 110/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0060
# Epoch 111/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0083 - val_loss: 0.0059
# Epoch 112/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0087 - val_loss: 0.0057
# Epoch 113/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0088 - val_loss: 0.0056
# Epoch 114/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0084 - val_loss: 0.0057
# Epoch 115/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 116/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0052
# Epoch 117/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0071 - val_loss: 0.0051
# Epoch 118/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0072 - val_loss: 0.0058
# Epoch 119/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 120/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0082 - val_loss: 0.0062
# Epoch 121/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 122/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0081 - val_loss: 0.0059
# Epoch 123/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0080 - val_loss: 0.0064
# Epoch 124/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0080 - val_loss: 0.0063
# Epoch 125/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0080 - val_loss: 0.0060
# Epoch 126/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0082 - val_loss: 0.0062
# Epoch 127/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0084 - val_loss: 0.0059
# Epoch 128/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0082 - val_loss: 0.0060
# Epoch 129/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 130/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 131/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0054
# Epoch 132/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0075 - val_loss: 0.0056
# Epoch 133/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0072 - val_loss: 0.0058
# Epoch 134/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 135/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 136/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 137/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 138/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 139/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 140/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 141/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0069 - val_loss: 0.0064
# Epoch 142/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 143/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 144/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0064
# Epoch 145/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 146/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 147/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0060
# Epoch 148/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 149/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 150/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0055
# Epoch 151/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 152/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 153/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0077 - val_loss: 0.0067
# Epoch 154/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 155/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0070 - val_loss: 0.0052
# Epoch 156/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 157/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0067 - val_loss: 0.0051
# Epoch 158/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 159/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0080 - val_loss: 0.0067
# Epoch 160/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0083 - val_loss: 0.0057
# Epoch 161/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0089 - val_loss: 0.0050
# Epoch 162/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0083 - val_loss: 0.0047
# Epoch 163/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0080 - val_loss: 0.0048
# Epoch 164/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0080 - val_loss: 0.0050
# Epoch 165/200
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0079 - val_loss: 0.0059
# Epoch 166/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0075 - val_loss: 0.0066
# Epoch 167/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0077 - val_loss: 0.0068
# Epoch 168/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 169/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0075 - val_loss: 0.0068
# Epoch 170/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 171/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0078 - val_loss: 0.0192
# Epoch 172/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0084 - val_loss: 0.0179
# Epoch 173/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0098 - val_loss: 0.0074
# Epoch 174/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0077 - val_loss: 0.0049
# Epoch 175/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 176/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 177/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0084 - val_loss: 0.0064
# Epoch 178/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0079 - val_loss: 0.0165
# Epoch 179/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0086 - val_loss: 0.0208
# Epoch 180/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0097 - val_loss: 0.0288
# Epoch 181/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0137 - val_loss: 0.0078
# Epoch 182/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0077 - val_loss: 0.0089
# Epoch 183/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0078 - val_loss: 0.0109
# Epoch 184/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0091 - val_loss: 0.0273
# Epoch 185/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0120 - val_loss: 0.0063
# Epoch 186/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0080 - val_loss: 0.0094
# Epoch 187/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0097 - val_loss: 0.0149
# Epoch 188/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0112 - val_loss: 0.0169
# Epoch 189/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0109 - val_loss: 0.0107
# Epoch 190/200
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0110 - val_loss: 0.0117
# Epoch 191/200
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0109 - val_loss: 0.0090
# Epoch 192/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0099 - val_loss: 0.0067
# Epoch 193/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0095 - val_loss: 0.0071
# Epoch 194/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 195/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 196/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 197/200
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 198/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0071 - val_loss: 0.0068
# Epoch 199/200
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 200/200
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0067 - val_loss: 0.0066

# %%
pyplot.figure(2)
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
train_xhat=model.predict(train_X)
yhat = model.predict(test_X)

# %%
trainPredict = scaler.inverse_transform(train_xhat)
train_yhat = scaler.inverse_transform([train_y])
testPredict = scaler.inverse_transform(yhat)
test_yhat = scaler.inverse_transform([test_y])

# %%
look_back= 1

trainPredictPlot = numpy.empty_like(scaled)    
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = numpy.empty_like(scaled)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):len(scaled)-1, :] = testPredict
pyplot.figure(figsize = (20, 4))
pyplot.plot(scaler.inverse_transform(scaled))
pyplot.plot(trainPredictPlot)
pyplot.plot(testPredictPlot)
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test Score: %.4f RMSE' % rmse)
test2 = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (test2))
test = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (test))
# Out:
# Test Score: 0.6401 RMSE
# Test Score: 0.4097 MAE
# Test Score: 0.1047 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()

# %% [markdown]
# #LSTM

# %%
import time
import numpy
from math import sqrt
from numpy import concatenate
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,SimpleRNN,GRU,Bidirectional
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]


    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  #header 第一列为编号  index_col为取索引的参数
values = dataset.values
values = values.astype('float32')  #转化为浮点型
scaler = MinMaxScaler(feature_range=(0, 1))    #归一化处理
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1)  #转化为监督学习  设计预测维数
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
regressor = Sequential()
regressor.add(LSTM(units = 500, return_sequences = True, input_shape = (train_X.shape[1],train_X.shape[2])))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 500, return_sequences = True ))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 500, return_sequences = True ))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 500, return_sequences=False ))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1,activation = 'sigmoid'))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
start = time.time()
print("Compilation Time : ", time.time() - start)

history = regressor.fit(train_X, train_y, epochs = 200, batch_size = 32 ,validation_data=(test_X, test_y), verbose=1,
                    shuffle=False)
# Out:
# Compilation Time :  4.482269287109375e-05
# Epoch 1/200
# 20/20 [==============================] - 12s 193ms/step - loss: 0.0673 - val_loss: 0.0384
# Epoch 2/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0656 - val_loss: 0.0400
# Epoch 3/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0569 - val_loss: 0.0395
# Epoch 4/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0275 - val_loss: 0.0072
# Epoch 5/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 6/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0081 - val_loss: 0.0051
# Epoch 7/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 8/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0063 - val_loss: 0.0048
# Epoch 9/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0073 - val_loss: 0.0048
# Epoch 10/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0085 - val_loss: 0.0052
# Epoch 11/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0097 - val_loss: 0.0073
# Epoch 12/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0093 - val_loss: 0.0088
# Epoch 13/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 14/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 15/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 16/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 17/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 18/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 19/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 20/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 21/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 22/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 23/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 24/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 25/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 26/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 27/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0067 - val_loss: 0.0068
# Epoch 28/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 29/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 30/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 31/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 32/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 33/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 34/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 35/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 36/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 37/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 38/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 39/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0067 - val_loss: 0.0068
# Epoch 40/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 41/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 42/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 43/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 44/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 45/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 46/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 47/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 48/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 49/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 50/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 51/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 52/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0063 - val_loss: 0.0066
# Epoch 53/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 54/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 55/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 56/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 57/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 58/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 59/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 60/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 61/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 62/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 63/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 64/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 65/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 66/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 67/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 68/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 69/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 70/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 71/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 72/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 73/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 74/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 75/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 76/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 77/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 78/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 79/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 80/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0063 - val_loss: 0.0057
# Epoch 81/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 82/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 83/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 84/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 85/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 86/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 87/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 88/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 89/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 90/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 91/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 92/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 93/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 94/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 95/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 96/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 97/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 98/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 99/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 100/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 101/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 102/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 103/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 104/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 105/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 106/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 107/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 108/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 109/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 110/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 111/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 112/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 113/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 114/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 115/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 116/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 117/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 118/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 119/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 120/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 121/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 122/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 123/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 124/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 125/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 126/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0071 - val_loss: 0.0058
# Epoch 127/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0071 - val_loss: 0.0058
# Epoch 128/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0072 - val_loss: 0.0054
# Epoch 129/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 130/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 131/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 132/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 133/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 134/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 135/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 136/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 137/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 138/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 139/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 140/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 141/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 142/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 143/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 144/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 145/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 146/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 147/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 148/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 149/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 150/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 151/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 152/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 153/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 154/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 155/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 156/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 157/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 158/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 159/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 160/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 161/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 162/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 163/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 164/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 165/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 166/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 167/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 168/200
# 20/20 [==============================] - 2s 101ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 169/200
# 20/20 [==============================] - 2s 101ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 170/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 171/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 172/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 173/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 174/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 175/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 176/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 177/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 178/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 179/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 180/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 181/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 182/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 183/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 184/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 185/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 186/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 187/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 188/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 189/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 190/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 191/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 192/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 193/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 194/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 195/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 196/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 197/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 198/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 199/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 200/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0057 - val_loss: 0.0052

# %%
pyplot.figure(2)
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
train_xhat=regressor.predict(train_X)
yhat = regressor.predict(test_X)

# %%
trainPredict = scaler.inverse_transform(train_xhat)
train_yhat = scaler.inverse_transform([train_y])
testPredict = scaler.inverse_transform(yhat)
test_yhat = scaler.inverse_transform([test_y])

# %%
look_back=1

trainPredictPlot = numpy.empty_like(scaled)    
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = numpy.empty_like(scaled)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):len(scaled)-1, :] = testPredict
pyplot.figure(figsize = (20, 4))
pyplot.plot(scaler.inverse_transform(scaled))
pyplot.plot(trainPredictPlot)
pyplot.plot(testPredictPlot)
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test Score: %.4f RMSE' % rmse)
test2 = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (test2))
test = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (test))
# Out:
# Test Score: 0.5717 RMSE
# Test Score: 0.3268 MAE
# Test Score: 0.0835 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()

# %% [markdown]
# #GRU

# %%
import time
import numpy
from math import sqrt
from numpy import concatenate
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,SimpleRNN,GRU,Bidirectional
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]


    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  #header 第一列为编号  index_col为取索引的参数
values = dataset.values
values = values.astype('float32')  #转化为浮点型
scaler = MinMaxScaler(feature_range=(0, 1))    #归一化处理
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1)  #转化为监督学习  设计预测维数
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
regressorGRU = Sequential()
regressorGRU.add(GRU(units=500, return_sequences=True, input_shape=(train_X.shape[1],train_X.shape[2])))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=500, return_sequences=True))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=500, return_sequences=True))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=500,return_sequences=False))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(Dense(units=1,activation = 'sigmoid'))
regressorGRU.compile(optimizer = 'adam', loss = 'mean_squared_error')
start = time.time()
print("Compilation Time : ", time.time() - start)

history = regressorGRU.fit(train_X, train_y, epochs = 200, batch_size = 32 ,validation_data=(test_X, test_y), verbose=1,
                    shuffle=False)
# Out:
# Compilation Time :  4.4345855712890625e-05
# Epoch 1/200
# 20/20 [==============================] - 12s 163ms/step - loss: 0.0658 - val_loss: 0.0382
# Epoch 2/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0364 - val_loss: 0.0095
# Epoch 3/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0069 - val_loss: 0.0060
# Epoch 4/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 5/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0110 - val_loss: 0.0053
# Epoch 6/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0095 - val_loss: 0.0058
# Epoch 7/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 8/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0078 - val_loss: 0.0048
# Epoch 9/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 10/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0097 - val_loss: 0.0049
# Epoch 11/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0118 - val_loss: 0.0067
# Epoch 12/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0120 - val_loss: 0.0093
# Epoch 13/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0103 - val_loss: 0.0101
# Epoch 14/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0092 - val_loss: 0.0099
# Epoch 15/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 16/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 17/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 18/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 19/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 20/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 21/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 22/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 23/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 24/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 25/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 26/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 27/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0076 - val_loss: 0.0078
# Epoch 28/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 29/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 30/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 31/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 32/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 33/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 34/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0080 - val_loss: 0.0080
# Epoch 35/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0076 - val_loss: 0.0078
# Epoch 36/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 37/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 38/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 39/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 40/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 41/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 42/200
# 20/20 [==============================] - 1s 73ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 43/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 44/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0069 - val_loss: 0.0073
# Epoch 45/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 46/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 47/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0070 - val_loss: 0.0073
# Epoch 48/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 49/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 50/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 51/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 52/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 53/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 54/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0083 - val_loss: 0.0080
# Epoch 55/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0088 - val_loss: 0.0086
# Epoch 56/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0088 - val_loss: 0.0136
# Epoch 57/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0107 - val_loss: 0.0153
# Epoch 58/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0135 - val_loss: 0.0198
# Epoch 59/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0154 - val_loss: 0.0353
# Epoch 60/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0205 - val_loss: 0.0470
# Epoch 61/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0204 - val_loss: 0.0070
# Epoch 62/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0121 - val_loss: 0.0065
# Epoch 63/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 64/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 65/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0135 - val_loss: 0.0174
# Epoch 66/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0087 - val_loss: 0.0074
# Epoch 67/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 68/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 69/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 70/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0077 - val_loss: 0.0079
# Epoch 71/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 72/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 73/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 74/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 75/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 76/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 77/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 78/200
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 79/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0063 - val_loss: 0.0065
# Epoch 80/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 81/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 82/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 83/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 84/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 85/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 86/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 87/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 88/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 89/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 90/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 91/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 92/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 93/200
# 20/20 [==============================] - 1s 73ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 94/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 95/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 96/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 97/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 98/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 99/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 100/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 101/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 102/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 103/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 104/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 105/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 106/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 107/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 108/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 109/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 110/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 111/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 112/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 113/200
# 20/20 [==============================] - 1s 76ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 114/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 115/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 116/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 117/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 118/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 119/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 120/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 121/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 122/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0077 - val_loss: 0.0063
# Epoch 123/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0080 - val_loss: 0.0061
# Epoch 124/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 125/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 126/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 127/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 128/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 129/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 130/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 131/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 132/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 133/200
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 134/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 135/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 136/200
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 137/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 138/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 139/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 140/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 141/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 142/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 143/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 144/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 145/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 146/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 147/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 148/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 149/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 150/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 151/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 152/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0098 - val_loss: 0.0071
# Epoch 153/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0099 - val_loss: 0.0069
# Epoch 154/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0082 - val_loss: 0.0057
# Epoch 155/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0084 - val_loss: 0.0064
# Epoch 156/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0075 - val_loss: 0.0061
# Epoch 157/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 158/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 159/200
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 160/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 161/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 162/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 163/200
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 164/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 165/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 166/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 167/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 168/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 169/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 170/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 171/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 172/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 173/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 174/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 175/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 176/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 177/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 178/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 179/200
# 20/20 [==============================] - 2s 75ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 180/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 181/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 182/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 183/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 184/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 185/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 186/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 187/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 188/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 189/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 190/200
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0106 - val_loss: 0.0080
# Epoch 191/200
# 20/20 [==============================] - 2s 76ms/step - loss: 0.0089 - val_loss: 0.0066
# Epoch 192/200
# 20/20 [==============================] - 2s 78ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 193/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 194/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 195/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 196/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 197/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 198/200
# 20/20 [==============================] - 2s 77ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 199/200
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 200/200
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0051 - val_loss: 0.0048

# %%
pyplot.figure(2)
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
train_xhat=regressorGRU.predict(train_X)
yhat = regressorGRU.predict(test_X)

# %%
trainPredict = scaler.inverse_transform(train_xhat)
train_yhat = scaler.inverse_transform([train_y])
testPredict = scaler.inverse_transform(yhat)
test_yhat = scaler.inverse_transform([test_y])

# %%
look_back=1

trainPredictPlot = numpy.empty_like(scaled)    
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = numpy.empty_like(scaled)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):len(scaled)-1, :] = testPredict
pyplot.figure(figsize = (20, 4))
pyplot.plot(scaler.inverse_transform(scaled))
pyplot.plot(trainPredictPlot)
pyplot.plot(testPredictPlot)
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test Score: %.4f RMSE' % rmse)
test2 = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (test2))
test = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (test))
# Out:
# Test Score: 0.5475 RMSE
# Test Score: 0.2998 MAE
# Test Score: 0.0766 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()

# %% [markdown]
# #BiLSTM

# %%
import time
import numpy
from math import sqrt
from numpy import concatenate
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,SimpleRNN,GRU,Bidirectional
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]


    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  
values = dataset.values
values = values.astype('float32')  
scaler = MinMaxScaler(feature_range=(0, 1))    
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1) 
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
regressorBilstm = Sequential()
regressorBilstm.add(Bidirectional(LSTM(units = 500, return_sequences = True, input_shape = (train_X.shape[1], train_X.shape[2]))))
regressorBilstm.add(Dropout(0.2))
regressorBilstm.add(Bidirectional(LSTM(units = 500, return_sequences = True)))
regressorBilstm.add(Dropout(0.2))
regressorBilstm.add(Bidirectional(LSTM(units = 500, return_sequences = True)))
regressorBilstm.add(Dropout(0.2))
regressorBilstm.add(Bidirectional(LSTM(units = 500 ,return_sequences=False)))
regressorBilstm.add(Dropout(0.2))
regressorBilstm.add(Dense(units = 1,activation = 'sigmoid'))
regressorBilstm.compile(optimizer = 'adam', loss = 'mean_squared_error')
start = time.time()
print("Compilation Time : ", time.time() - start)

history = regressorBilstm.fit(train_X, train_y, epochs = 200, batch_size = 32 ,validation_data=(test_X, test_y), verbose=1,
                    shuffle=False)
# Out:
# Compilation Time :  4.172325134277344e-05
# Epoch 1/200
# 20/20 [==============================] - 28s 454ms/step - loss: 0.0673 - val_loss: 0.0386
# Epoch 2/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0589 - val_loss: 0.0338
# Epoch 3/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0266 - val_loss: 0.0056
# Epoch 4/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0158 - val_loss: 0.0084
# Epoch 5/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0126 - val_loss: 0.0115
# Epoch 6/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 7/200
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 8/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 9/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 10/200
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 11/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0081 - val_loss: 0.0075
# Epoch 12/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0080 - val_loss: 0.0074
# Epoch 13/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0079 - val_loss: 0.0075
# Epoch 14/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 15/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 16/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 17/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0077 - val_loss: 0.0073
# Epoch 18/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 19/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 20/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 21/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 22/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 23/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 24/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 25/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 26/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 27/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 28/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 29/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 30/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 31/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 32/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 33/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 34/200
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 35/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 36/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 37/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 38/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 39/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0073 - val_loss: 0.0070
# Epoch 40/200
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0073 - val_loss: 0.0070
# Epoch 41/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0073 - val_loss: 0.0069
# Epoch 42/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 43/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0073 - val_loss: 0.0070
# Epoch 44/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 45/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0072 - val_loss: 0.0069
# Epoch 46/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 47/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 48/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 49/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 50/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 51/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 52/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0073 - val_loss: 0.0070
# Epoch 53/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0071 - val_loss: 0.0067
# Epoch 54/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0071 - val_loss: 0.0068
# Epoch 55/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0069 - val_loss: 0.0069
# Epoch 56/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 57/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 58/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 59/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 60/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 61/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 62/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 63/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0065 - val_loss: 0.0063
# Epoch 64/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 65/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 66/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 67/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 68/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 69/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 70/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 71/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 72/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 73/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 74/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 75/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 76/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0061 - val_loss: 0.0056
# Epoch 77/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0061 - val_loss: 0.0056
# Epoch 78/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 79/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 80/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 81/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 82/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 83/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 84/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 85/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 86/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 87/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 88/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 89/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 90/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 91/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 92/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 93/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 94/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 95/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0077 - val_loss: 0.0063
# Epoch 96/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0082 - val_loss: 0.0070
# Epoch 97/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0091 - val_loss: 0.0127
# Epoch 98/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0127 - val_loss: 0.0145
# Epoch 99/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0148 - val_loss: 0.0168
# Epoch 100/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0097 - val_loss: 0.0191
# Epoch 101/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0163 - val_loss: 0.0093
# Epoch 102/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0128 - val_loss: 0.0066
# Epoch 103/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0091 - val_loss: 0.0048
# Epoch 104/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0061 - val_loss: 0.0045
# Epoch 105/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 106/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 107/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 108/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 109/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 110/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 111/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 112/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 113/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 114/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 115/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 116/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 117/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 118/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 119/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 120/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 121/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 122/200
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 123/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 124/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 125/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 126/200
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 127/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 128/200
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 129/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 130/200
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 131/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 132/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 133/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 134/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 135/200
# 20/20 [==============================] - 5s 247ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 136/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 137/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 138/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 139/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 140/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 141/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0064 - val_loss: 0.0051
# Epoch 142/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0066 - val_loss: 0.0051
# Epoch 143/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 144/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 145/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 146/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0061 - val_loss: 0.0053
# Epoch 147/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 148/200
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 149/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 150/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 151/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 152/200
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 153/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 154/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 155/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 156/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 157/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 158/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 159/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 160/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 161/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 162/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 163/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 164/200
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 165/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0059 - val_loss: 0.0051
# Epoch 166/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 167/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 168/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 169/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 170/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 171/200
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 172/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 173/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 174/200
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 175/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 176/200
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 177/200
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 178/200
# 20/20 [==============================] - 5s 248ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 179/200
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 180/200
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 181/200
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 182/200
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 183/200
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 184/200
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 185/200
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 186/200
# 20/20 [==============================] - 5s 235ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 187/200
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 188/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 189/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 190/200
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 191/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 192/200
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 193/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 194/200
# 20/20 [==============================] - 5s 245ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 195/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 196/200
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 197/200
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 198/200
# 20/20 [==============================] - 5s 242ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 199/200
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 200/200
# 20/20 [==============================] - 5s 233ms/step - loss: 0.0064 - val_loss: 0.0055

# %%
pyplot.figure(2)
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
train_xhat=regressorBilstm.predict(train_X)
yhat = regressorBilstm.predict(test_X)

# %%
trainPredict = scaler.inverse_transform(train_xhat)
train_yhat = scaler.inverse_transform([train_y])
testPredict = scaler.inverse_transform(yhat)
test_yhat = scaler.inverse_transform([test_y])

# %%
look_back=1

trainPredictPlot = numpy.empty_like(scaled)    
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = numpy.empty_like(scaled)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):len(scaled)-1, :] = testPredict
pyplot.figure(figsize = (20, 4))
pyplot.plot(scaler.inverse_transform(scaled))
pyplot.plot(trainPredictPlot)
pyplot.plot(testPredictPlot)
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test Score: %.4f RMSE' % rmse)
test2 = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (test2))
test = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (test))
# Out:
# Test Score: 0.5855 RMSE
# Test Score: 0.3429 MAE
# Test Score: 0.0876 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()

# %% [markdown]
# ## Improved RNN

# %%
import time
import numpy
from math import sqrt
from numpy import concatenate
import numpy as np
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM,SimpleRNN,GRU,Bidirectional
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]


    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
dataset = read_csv('/content/Ulsoordata.csv', header=0, usecols=[3])  
values = dataset.values
values = values.astype('float32')  
scaler = MinMaxScaler(feature_range=(0, 1))    
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1) 
values = reframed.values
threshold = int(0.87 * len(reframed))
train = values[:threshold, :]
test = values[threshold:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
regressorIMRNN = Sequential()
regressorIMRNN.add((SimpleRNN(units = 500, return_sequences = True, input_shape = (train_X.shape[1], train_X.shape[2]))))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add((SimpleRNN(units = 500, return_sequences = True)))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add((LSTM(units = 500, return_sequences = True )))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add((LSTM(units = 500, return_sequences = True)))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add((GRU(units = 500, return_sequences = True )))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add((GRU(units = 500, return_sequences = True)))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add((SimpleRNN(units = 500, return_sequences = False)))
regressorIMRNN.add(Dropout(0.2))
regressorIMRNN.add(Dense(units = 1,activation = 'sigmoid'))
regressorIMRNN.compile(optimizer = 'adam', loss = 'mean_squared_error')
start = time.time()
print("Compilation Time : ", time.time() - start)

history = regressorIMRNN.fit(train_X, train_y, epochs = 200, batch_size = 32 ,validation_data=(test_X, test_y), verbose=1,
                    shuffle=False)
# Out:
# Compilation Time :  3.743171691894531e-05
# Epoch 1/200
# 20/20 [==============================] - 13s 195ms/step - loss: 0.0697 - val_loss: 0.0440
# Epoch 2/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0661 - val_loss: 0.0222
# Epoch 3/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0173 - val_loss: 0.0239
# Epoch 4/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0259 - val_loss: 0.0111
# Epoch 5/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0240 - val_loss: 0.0097
# Epoch 6/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0096 - val_loss: 0.0086
# Epoch 7/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0090 - val_loss: 0.0153
# Epoch 8/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0173 - val_loss: 0.0195
# Epoch 9/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0153 - val_loss: 0.0099
# Epoch 10/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0089 - val_loss: 0.0078
# Epoch 11/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 12/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0089 - val_loss: 0.0192
# Epoch 13/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0214 - val_loss: 0.0177
# Epoch 14/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0176 - val_loss: 0.0116
# Epoch 15/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0102 - val_loss: 0.0049
# Epoch 16/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0060 - val_loss: 0.0099
# Epoch 17/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0102 - val_loss: 0.0197
# Epoch 18/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0168 - val_loss: 0.0348
# Epoch 19/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0169 - val_loss: 0.0183
# Epoch 20/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0115 - val_loss: 0.0122
# Epoch 21/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0111 - val_loss: 0.0163
# Epoch 22/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0147 - val_loss: 0.0195
# Epoch 23/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0193 - val_loss: 0.0152
# Epoch 24/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0149 - val_loss: 0.0218
# Epoch 25/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0139 - val_loss: 0.0098
# Epoch 26/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0134 - val_loss: 0.0131
# Epoch 27/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0152 - val_loss: 0.0184
# Epoch 28/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0118 - val_loss: 0.0241
# Epoch 29/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0127 - val_loss: 0.0588
# Epoch 30/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0172 - val_loss: 0.0102
# Epoch 31/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0090 - val_loss: 0.0245
# Epoch 32/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0179 - val_loss: 0.0193
# Epoch 33/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0140 - val_loss: 0.0086
# Epoch 34/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0138 - val_loss: 0.0045
# Epoch 35/200
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0081 - val_loss: 0.0050
# Epoch 36/200
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0080 - val_loss: 0.0053
# Epoch 37/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0099 - val_loss: 0.0051
# Epoch 38/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0102 - val_loss: 0.0063
# Epoch 39/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0119 - val_loss: 0.0132
# Epoch 40/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0105 - val_loss: 0.0082
# Epoch 41/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0095 - val_loss: 0.0067
# Epoch 42/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0087 - val_loss: 0.0064
# Epoch 43/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0098 - val_loss: 0.0085
# Epoch 44/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0095 - val_loss: 0.0089
# Epoch 45/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0089 - val_loss: 0.0075
# Epoch 46/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0082 - val_loss: 0.0068
# Epoch 47/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0080 - val_loss: 0.0066
# Epoch 48/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0082 - val_loss: 0.0057
# Epoch 49/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0083 - val_loss: 0.0065
# Epoch 50/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0080 - val_loss: 0.0063
# Epoch 51/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 52/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0076 - val_loss: 0.0056
# Epoch 53/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0079 - val_loss: 0.0053
# Epoch 54/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0092 - val_loss: 0.0065
# Epoch 55/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0095 - val_loss: 0.0076
# Epoch 56/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0082 - val_loss: 0.0056
# Epoch 57/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0073 - val_loss: 0.0052
# Epoch 58/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 59/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 60/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0077 - val_loss: 0.0054
# Epoch 61/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0083 - val_loss: 0.0057
# Epoch 62/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0084 - val_loss: 0.0056
# Epoch 63/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0094 - val_loss: 0.0060
# Epoch 64/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0091 - val_loss: 0.0058
# Epoch 65/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0076 - val_loss: 0.0053
# Epoch 66/200
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0089 - val_loss: 0.0056
# Epoch 67/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0093 - val_loss: 0.0072
# Epoch 68/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0069 - val_loss: 0.0052
# Epoch 69/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 70/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0061 - val_loss: 0.0046
# Epoch 71/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 72/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 73/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 74/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0066 - val_loss: 0.0050
# Epoch 75/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0083 - val_loss: 0.0050
# Epoch 76/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0090 - val_loss: 0.0061
# Epoch 77/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0085 - val_loss: 0.0057
# Epoch 78/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0078 - val_loss: 0.0051
# Epoch 79/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0066 - val_loss: 0.0049
# Epoch 80/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0064 - val_loss: 0.0050
# Epoch 81/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0066 - val_loss: 0.0048
# Epoch 82/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0067 - val_loss: 0.0051
# Epoch 83/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0078 - val_loss: 0.0052
# Epoch 84/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0080 - val_loss: 0.0175
# Epoch 85/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0108 - val_loss: 0.0047
# Epoch 86/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 87/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0069 - val_loss: 0.0100
# Epoch 88/200
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 89/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 90/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 91/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0115 - val_loss: 0.0083
# Epoch 92/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 93/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0067 - val_loss: 0.0045
# Epoch 94/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0059 - val_loss: 0.0046
# Epoch 95/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 96/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 97/200
# 20/20 [==============================] - 2s 101ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 98/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0080 - val_loss: 0.0050
# Epoch 99/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0108 - val_loss: 0.0063
# Epoch 100/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0125 - val_loss: 0.0068
# Epoch 101/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0130 - val_loss: 0.0105
# Epoch 102/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0151 - val_loss: 0.0050
# Epoch 103/200
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0081 - val_loss: 0.0052
# Epoch 104/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 105/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0086 - val_loss: 0.0055
# Epoch 106/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0104 - val_loss: 0.0085
# Epoch 107/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0088 - val_loss: 0.0072
# Epoch 108/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0068 - val_loss: 0.0055
# Epoch 109/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 110/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 111/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0073 - val_loss: 0.0054
# Epoch 112/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0070 - val_loss: 0.0054
# Epoch 113/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 114/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 115/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0081 - val_loss: 0.0050
# Epoch 116/200
# 20/20 [==============================] - 2s 101ms/step - loss: 0.0077 - val_loss: 0.0053
# Epoch 117/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0070 - val_loss: 0.0049
# Epoch 118/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0081 - val_loss: 0.0056
# Epoch 119/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0081 - val_loss: 0.0069
# Epoch 120/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0068 - val_loss: 0.0056
# Epoch 121/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 122/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0062 - val_loss: 0.0049
# Epoch 123/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 124/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 125/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 126/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0054 - val_loss: 0.0047
# Epoch 127/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 128/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 129/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 130/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 131/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 132/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 133/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0088 - val_loss: 0.0056
# Epoch 134/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0099 - val_loss: 0.0068
# Epoch 135/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 136/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 137/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 138/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 139/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 140/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 141/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 142/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 143/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0081 - val_loss: 0.0055
# Epoch 144/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0078 - val_loss: 0.0054
# Epoch 145/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 146/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 147/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 148/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 149/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 150/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 151/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 152/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 153/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 154/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 155/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 156/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 157/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0067 - val_loss: 0.0052
# Epoch 158/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 159/200
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0057 - val_loss: 0.0051
# Epoch 160/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 161/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 162/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 163/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0071 - val_loss: 0.0199
# Epoch 164/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0094 - val_loss: 0.0091
# Epoch 165/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0090 - val_loss: 0.0063
# Epoch 166/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 167/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0071 - val_loss: 0.0129
# Epoch 168/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0112 - val_loss: 0.0455
# Epoch 169/200
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0229 - val_loss: 0.0052
# Epoch 170/200
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0172 - val_loss: 0.0102
# Epoch 171/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0183 - val_loss: 0.0111
# Epoch 172/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0160 - val_loss: 0.0095
# Epoch 173/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0088 - val_loss: 0.0121
# Epoch 174/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0096 - val_loss: 0.0113
# Epoch 175/200
# 20/20 [==============================] - 2s 98ms/step - loss: 0.0105 - val_loss: 0.0113
# Epoch 176/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0166 - val_loss: 0.0064
# Epoch 177/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0130 - val_loss: 0.0063
# Epoch 178/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0088 - val_loss: 0.0047
# Epoch 179/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 180/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 181/200
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0070 - val_loss: 0.0052
# Epoch 182/200
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0091 - val_loss: 0.0065
# Epoch 183/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0105 - val_loss: 0.0101
# Epoch 184/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0083 - val_loss: 0.0072
# Epoch 185/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 186/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 187/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 188/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 189/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 190/200
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 191/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 192/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 193/200
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0068 - val_loss: 0.0056
# Epoch 194/200
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 195/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0069 - val_loss: 0.0060
# Epoch 196/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 197/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 198/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 199/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 200/200
# 20/20 [==============================] - 2s 95ms/step - loss: 0.0067 - val_loss: 0.0058

# %%
pyplot.figure(2)
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
train_xhat=regressorIMRNN.predict(train_X)
yhat = regressorIMRNN.predict(test_X)

# %%
trainPredict = scaler.inverse_transform(train_xhat)
train_yhat = scaler.inverse_transform([train_y])
testPredict = scaler.inverse_transform(yhat)
test_yhat = scaler.inverse_transform([test_y])

# %%
look_back=1

trainPredictPlot = numpy.empty_like(scaled)    
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
testPredictPlot = numpy.empty_like(scaled)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict):len(scaled)-1, :] = testPredict
pyplot.figure(figsize = (20, 4))
pyplot.plot(scaler.inverse_transform(scaled))
pyplot.plot(trainPredictPlot)
pyplot.plot(testPredictPlot)
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test Score: %.4f RMSE' % rmse)
test2 = np.abs(mean_squared_error(inv_y, inv_yhat)).mean()
print('Test Score: %.4f MAE' % (test2))
test = np.mean(np.abs(mean_squared_error(inv_y, inv_yhat) / inv_y))
print('Test Score: %.4f MAPE' % (test))
# Out:
# Test Score: 0.6028 RMSE
# Test Score: 0.3634 MAE
# Test Score: 0.0929 MAPE

# %%
pyplot.plot([x for x in range(1, inv_yhat.shape[0]+1)], inv_yhat, linestyle='--', color='red', label='prediction')
pyplot.plot([x for x in range(1, inv_y.shape[0]+1)], inv_y, linestyle='-', color='blue', label='actual')
pyplot.legend(loc=1, prop={'size': 12})
pyplot.show()
